# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta
from itertools import permutations
import os

# %%
API_KEY = "vSmtvpdrv8xGtZG7YYgSiPg3irGrpWbd"
currencies = ["USD", "EUR", "JPY", "GBP", "CNH", "AUD", "CAD", "CHF", "HKD", "SGD"]
currency_pairs = [f"C:{a}{b}" for a, b in permutations(currencies, 2)]

start_date = datetime(2026, 6, 1)
end_date = datetime(2026, 7, 3)

output_folder = "Data"
os.makedirs(output_folder, exist_ok=True)

# %%
def fetch_intraday_forex_data(api_key, date, ticker, timespan="minute", multiplier=1, max_retries=3):
    url = f"https://api.polygon.io/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{date}/{date}"
    
    params = {
        "adjusted": "true",
        "sort": "asc",
        "limit": 50000,
        "apiKey": api_key
    }

    retries = 0
    while retries <= max_retries:
        try:
            response = requests.get(url, params=params)
            if response.status_code == 429:
                print(f"Rate limit hit for {ticker} on {date}. Sleeping 60 seconds...")
                time.sleep(60)
                retries += 1
                continue
            elif response.status_code != 200:
                print(f"Error {response.status_code} for {ticker} on {date}: {response.text}")
                return None

            data = response.json()
            if 'results' not in data or not data['results']:
                print(f"No results for {ticker} on {date}")
                return None

            return pd.DataFrame([{
                "date": date,
                "pair": ticker[2:],
                "timestamp": pd.to_datetime(r['t'], unit='ms'),
                "open": r.get("o", 0),
                "high": r.get("h", 0),
                "low": r.get("l", 0),
                "close": r.get("c", 0),
                "volume": r.get("v", 0)
            } for r in data["results"]])

        except requests.exceptions.RequestException as e:
            print(f"🌐 Network error for {ticker} on {date}: {e}")
            time.sleep(60)
            retries += 1

    print(f"Failed to fetch data for {ticker} on {date} after {max_retries} retries.")
    return None

# %%
current_date = start_date
while current_date <= end_date:
    date_str = current_date.strftime('%Y-%m-%d')
    filename = os.path.join(output_folder, f"forex_intraday_{date_str}.csv")

    if os.path.exists(filename):
        print(f"{filename} already exists, skipping.")
        current_date += timedelta(days=1)
        continue

    print(f"\nFetching data for {date_str}...")
    all_data = []

    for i, pair in enumerate(currency_pairs):
        print(f"  [{i+1}/{len(currency_pairs)}] {pair}")
        df = fetch_intraday_forex_data(API_KEY, date_str, pair)
        if df is not None:
            all_data.append(df)
        time.sleep(1.2)

    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        print(f"Got {len(final_df)} rows.")
    else:
        final_df = pd.DataFrame(columns=[
            "date", "pair", "timestamp", "open", "high", "low", "close", "volume"
        ])
        print(f"No data for {date_str}, saving empty file.")

    final_df.to_csv(filename, index=False)
    print(f"Saved: {filename}")
    current_date += timedelta(days=1)
# Out:
# Fetching data for 2026-06-01...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
# Rate limit hit for C:USDCAD on 2026-06-01. Sleeping 60 seconds...
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
# Rate limit hit for C:EURCAD on 2026-06-01. Sleeping 60 seconds...
#   [16/90] C:EURCHF
#   [17/90] C:EURHKD
#   [18/90] C:EURSGD
#   [19/90] C:JPYUSD
#   [20/90] C:JPYEUR
# Rate limit hit for C:JPYEUR on 2026-06-01. Sleeping 60 seconds...
#   [21/90] C:JPYGBP
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-01
#   [23/90] C:JPYAUD
#   [24/90] C:JPYCAD
#   [25/90] C:JPYCHF
# Rate limit hit for C:JPYCHF on 2026-06-01. Sleeping 60 seconds...
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# No results for C:JPYSGD on 2026-06-01
#   [28/90] C:GBPUSD
#   [29/90] C:GBPEUR
#   [30/90] C:GBPJPY
# Rate limit hit for C:GBPJPY on 2026-06-01. Sleeping 60 seconds...
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
#   [33/90] C:GBPCAD
#   [34/90] C:GBPCHF
#   [35/90] C:GBPHKD
#   [36/90] C:GBPSGD
# Rate limit hit for C:GBPSGD on 2026-06-01. Sleeping 60 seconds...
#   [37/90] C:CNHUSD
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-01
#   [39/90] C:CNHJPY
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-01
#   [41/90] C:CNHAUD
# Rate limit hit for C:CNHAUD on 2026-06-01. Sleeping 60 seconds...
# No results for C:CNHAUD on 2026-06-01
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-01
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-01
#   [44/90] C:CNHHKD
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-01
#   [46/90] C:AUDUSD
# Rate limit hit for C:AUDUSD on 2026-06-01. Sleeping 60 seconds...
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
#   [49/90] C:AUDGBP
#   [50/90] C:AUDCNH
#   [51/90] C:AUDCAD
# Rate limit hit for C:AUDCAD on 2026-06-01. Sleeping 60 seconds...
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
#   [54/90] C:AUDSGD
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
#   [57/90] C:CADJPY
# Rate limit hit for C:CADJPY on 2026-06-01. Sleeping 60 seconds...
#   [58/90] C:CADGBP
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-01
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
#   [62/90] C:CADHKD
# Rate limit hit for C:CADHKD on 2026-06-01. Sleeping 60 seconds...
#   [63/90] C:CADSGD
#   [64/90] C:CHFUSD
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
#   [67/90] C:CHFGBP
# Rate limit hit for C:CHFGBP on 2026-06-01. Sleeping 60 seconds...
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-01
#   [69/90] C:CHFAUD
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
# Rate limit hit for C:CHFSGD on 2026-06-01. Sleeping 60 seconds...
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
#   [77/90] C:HKDCNH
# Rate limit hit for C:HKDCNH on 2026-06-01. Sleeping 60 seconds...
# No results for C:HKDCNH on 2026-06-01
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
#   [82/90] C:SGDUSD
# Rate limit hit for C:SGDUSD on 2026-06-01. Sleeping 60 seconds...
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# No results for C:SGDCNH on 2026-06-01
#   [87/90] C:SGDAUD
# Rate limit hit for C:SGDAUD on 2026-06-01. Sleeping 60 seconds...
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
#   [90/90] C:SGDHKD
# Got 111198 rows.
# Saved: Data/forex_intraday_2026-06-01.csv
#
# Fetching data for 2026-06-02...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
# Rate limit hit for C:USDJPY on 2026-06-02. Sleeping 60 seconds...
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
# Rate limit hit for C:USDHKD on 2026-06-02. Sleeping 60 seconds...
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
# Rate limit hit for C:EURCNH on 2026-06-02. Sleeping 60 seconds...
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
#   [16/90] C:EURCHF
#   [17/90] C:EURHKD
#   [18/90] C:EURSGD
# Rate limit hit for C:EURSGD on 2026-06-02. Sleeping 60 seconds...
#   [19/90] C:JPYUSD
#   [20/90] C:JPYEUR
#   [21/90] C:JPYGBP
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-02
#   [23/90] C:JPYAUD
# Rate limit hit for C:JPYAUD on 2026-06-02. Sleeping 60 seconds...
#   [24/90] C:JPYCAD
#   [25/90] C:JPYCHF
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# No results for C:JPYSGD on 2026-06-02
#   [28/90] C:GBPUSD
#   [29/90] C:GBPEUR
# Rate limit hit for C:GBPEUR on 2026-06-02. Sleeping 60 seconds...
#   [30/90] C:GBPJPY
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
#   [33/90] C:GBPCAD
#   [34/90] C:GBPCHF
# Rate limit hit for C:GBPCHF on 2026-06-02. Sleeping 60 seconds...
#   [35/90] C:GBPHKD
#   [36/90] C:GBPSGD
#   [37/90] C:CNHUSD
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-02
#   [39/90] C:CNHJPY
# Rate limit hit for C:CNHJPY on 2026-06-02. Sleeping 60 seconds...
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-02
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-02
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-02
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-02
#   [44/90] C:CNHHKD
# Rate limit hit for C:CNHHKD on 2026-06-02. Sleeping 60 seconds...
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-02
#   [46/90] C:AUDUSD
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
#   [49/90] C:AUDGBP
#   [50/90] C:AUDCNH
#   [51/90] C:AUDCAD
# Rate limit hit for C:AUDCAD on 2026-06-02. Sleeping 60 seconds...
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
#   [54/90] C:AUDSGD
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
# Rate limit hit for C:CADEUR on 2026-06-02. Sleeping 60 seconds...
#   [57/90] C:CADJPY
#   [58/90] C:CADGBP
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-02
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
# Rate limit hit for C:CADCHF on 2026-06-02. Sleeping 60 seconds...
#   [62/90] C:CADHKD
#   [63/90] C:CADSGD
#   [64/90] C:CHFUSD
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
# Rate limit hit for C:CHFJPY on 2026-06-02. Sleeping 60 seconds...
#   [67/90] C:CHFGBP
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-02
#   [69/90] C:CHFAUD
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
# Rate limit hit for C:CHFSGD on 2026-06-02. Sleeping 60 seconds...
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
#   [77/90] C:HKDCNH
# Rate limit hit for C:HKDCNH on 2026-06-02. Sleeping 60 seconds...
# No results for C:HKDCNH on 2026-06-02
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
#   [82/90] C:SGDUSD
# Rate limit hit for C:SGDUSD on 2026-06-02. Sleeping 60 seconds...
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# No results for C:SGDCNH on 2026-06-02
#   [87/90] C:SGDAUD
# Rate limit hit for C:SGDAUD on 2026-06-02. Sleeping 60 seconds...
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
#   [90/90] C:SGDHKD
# Got 106382 rows.
# Saved: Data/forex_intraday_2026-06-02.csv
#
# Fetching data for 2026-06-03...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
# Rate limit hit for C:USDJPY on 2026-06-03. Sleeping 60 seconds...
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
#   [7/90] C:USDCHF
# Rate limit hit for C:USDCHF on 2026-06-03. Sleeping 60 seconds...
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
# Rate limit hit for C:EURGBP on 2026-06-03. Sleeping 60 seconds...
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
#   [16/90] C:EURCHF
#   [17/90] C:EURHKD
# Rate limit hit for C:EURHKD on 2026-06-03. Sleeping 60 seconds...
#   [18/90] C:EURSGD
#   [19/90] C:JPYUSD
#   [20/90] C:JPYEUR
#   [21/90] C:JPYGBP
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-03
#   [23/90] C:JPYAUD
# Rate limit hit for C:JPYAUD on 2026-06-03. Sleeping 60 seconds...
#   [24/90] C:JPYCAD
#   [25/90] C:JPYCHF
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# No results for C:JPYSGD on 2026-06-03
#   [28/90] C:GBPUSD
# Rate limit hit for C:GBPUSD on 2026-06-03. Sleeping 60 seconds...
#   [29/90] C:GBPEUR
#   [30/90] C:GBPJPY
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
#   [33/90] C:GBPCAD
# Rate limit hit for C:GBPCAD on 2026-06-03. Sleeping 60 seconds...
#   [34/90] C:GBPCHF
#   [35/90] C:GBPHKD
#   [36/90] C:GBPSGD
#   [37/90] C:CNHUSD
#   [38/90] C:CNHEUR
# Rate limit hit for C:CNHEUR on 2026-06-03. Sleeping 60 seconds...
# No results for C:CNHEUR on 2026-06-03
#   [39/90] C:CNHJPY
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-03
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-03
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-03
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-03
#   [44/90] C:CNHHKD
# Rate limit hit for C:CNHHKD on 2026-06-03. Sleeping 60 seconds...
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-03
#   [46/90] C:AUDUSD
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
#   [49/90] C:AUDGBP
# Rate limit hit for C:AUDGBP on 2026-06-03. Sleeping 60 seconds...
#   [50/90] C:AUDCNH
#   [51/90] C:AUDCAD
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
#   [54/90] C:AUDSGD
# Rate limit hit for C:AUDSGD on 2026-06-03. Sleeping 60 seconds...
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
#   [57/90] C:CADJPY
#   [58/90] C:CADGBP
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-03
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
#   [62/90] C:CADHKD
#   [63/90] C:CADSGD
#   [64/90] C:CHFUSD
# Rate limit hit for C:CHFUSD on 2026-06-03. Sleeping 60 seconds...
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
#   [67/90] C:CHFGBP
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-03
#   [69/90] C:CHFAUD
# Rate limit hit for C:CHFAUD on 2026-06-03. Sleeping 60 seconds...
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
# Rate limit hit for C:HKDEUR on 2026-06-03. Sleeping 60 seconds...
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
#   [77/90] C:HKDCNH
# No results for C:HKDCNH on 2026-06-03
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
# Rate limit hit for C:HKDCAD on 2026-06-03. Sleeping 60 seconds...
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
#   [82/90] C:SGDUSD
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
# Rate limit hit for C:SGDJPY on 2026-06-03. Sleeping 60 seconds...
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# No results for C:SGDCNH on 2026-06-03
#   [87/90] C:SGDAUD
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
# Rate limit hit for C:SGDCHF on 2026-06-03. Sleeping 60 seconds...
#   [90/90] C:SGDHKD
# Got 107137 rows.
# Saved: Data/forex_intraday_2026-06-03.csv
#
# Fetching data for 2026-06-04...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
# Rate limit hit for C:USDCNH on 2026-06-04. Sleeping 60 seconds...
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
# Rate limit hit for C:EURAUD on 2026-06-04. Sleeping 60 seconds...
#   [15/90] C:EURCAD
#   [16/90] C:EURCHF
#   [17/90] C:EURHKD
#   [18/90] C:EURSGD
#   [19/90] C:JPYUSD
# Rate limit hit for C:JPYUSD on 2026-06-04. Sleeping 60 seconds...
#   [20/90] C:JPYEUR
#   [21/90] C:JPYGBP
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-04
#   [23/90] C:JPYAUD
#   [24/90] C:JPYCAD
# Rate limit hit for C:JPYCAD on 2026-06-04. Sleeping 60 seconds...
#   [25/90] C:JPYCHF
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# No results for C:JPYSGD on 2026-06-04
#   [28/90] C:GBPUSD
#   [29/90] C:GBPEUR
# Rate limit hit for C:GBPEUR on 2026-06-04. Sleeping 60 seconds...
#   [30/90] C:GBPJPY
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
#   [33/90] C:GBPCAD
#   [34/90] C:GBPCHF
#   [35/90] C:GBPHKD
# Rate limit hit for C:GBPHKD on 2026-06-04. Sleeping 60 seconds...
#   [36/90] C:GBPSGD
#   [37/90] C:CNHUSD
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-04
#   [39/90] C:CNHJPY
#   [40/90] C:CNHGBP
# Rate limit hit for C:CNHGBP on 2026-06-04. Sleeping 60 seconds...
# No results for C:CNHGBP on 2026-06-04
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-04
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-04
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-04
#   [44/90] C:CNHHKD
#   [45/90] C:CNHSGD
# Rate limit hit for C:CNHSGD on 2026-06-04. Sleeping 60 seconds...
# No results for C:CNHSGD on 2026-06-04
#   [46/90] C:AUDUSD
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
#   [49/90] C:AUDGBP
#   [50/90] C:AUDCNH
# Rate limit hit for C:AUDCNH on 2026-06-04. Sleeping 60 seconds...
#   [51/90] C:AUDCAD
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
#   [54/90] C:AUDSGD
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
#   [57/90] C:CADJPY
# Rate limit hit for C:CADJPY on 2026-06-04. Sleeping 60 seconds...
#   [58/90] C:CADGBP
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-04
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
#   [62/90] C:CADHKD
# Rate limit hit for C:CADHKD on 2026-06-04. Sleeping 60 seconds...
#   [63/90] C:CADSGD
#   [64/90] C:CHFUSD
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
#   [67/90] C:CHFGBP
# Rate limit hit for C:CHFGBP on 2026-06-04. Sleeping 60 seconds...
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-04
#   [69/90] C:CHFAUD
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
# Rate limit hit for C:HKDGBP on 2026-06-04. Sleeping 60 seconds...
#   [77/90] C:HKDCNH
# No results for C:HKDCNH on 2026-06-04
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
# Rate limit hit for C:HKDSGD on 2026-06-04. Sleeping 60 seconds...
#   [82/90] C:SGDUSD
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# Rate limit hit for C:SGDCNH on 2026-06-04. Sleeping 60 seconds...
# No results for C:SGDCNH on 2026-06-04
#   [87/90] C:SGDAUD
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
#   [90/90] C:SGDHKD
# Got 106631 rows.
# Saved: Data/forex_intraday_2026-06-04.csv
#
# Fetching data for 2026-06-05...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
# Rate limit hit for C:USDCAD on 2026-06-05. Sleeping 60 seconds...
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
#   [11/90] C:EURJPY
# Rate limit hit for C:EURJPY on 2026-06-05. Sleeping 60 seconds...
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
#   [16/90] C:EURCHF
# Rate limit hit for C:EURCHF on 2026-06-05. Sleeping 60 seconds...
#   [17/90] C:EURHKD
#   [18/90] C:EURSGD
#   [19/90] C:JPYUSD
#   [20/90] C:JPYEUR
#   [21/90] C:JPYGBP
# Rate limit hit for C:JPYGBP on 2026-06-05. Sleeping 60 seconds...
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-05
#   [23/90] C:JPYAUD
#   [24/90] C:JPYCAD
#   [25/90] C:JPYCHF
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# Rate limit hit for C:JPYSGD on 2026-06-05. Sleeping 60 seconds...
# No results for C:JPYSGD on 2026-06-05
#   [28/90] C:GBPUSD
#   [29/90] C:GBPEUR
#   [30/90] C:GBPJPY
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
# Rate limit hit for C:GBPAUD on 2026-06-05. Sleeping 60 seconds...
#   [33/90] C:GBPCAD
#   [34/90] C:GBPCHF
#   [35/90] C:GBPHKD
#   [36/90] C:GBPSGD
#   [37/90] C:CNHUSD
# Rate limit hit for C:CNHUSD on 2026-06-05. Sleeping 60 seconds...
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-05
#   [39/90] C:CNHJPY
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-05
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-05
#   [42/90] C:CNHCAD
# Rate limit hit for C:CNHCAD on 2026-06-05. Sleeping 60 seconds...
# No results for C:CNHCAD on 2026-06-05
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-05
#   [44/90] C:CNHHKD
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-05
#   [46/90] C:AUDUSD
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
# Rate limit hit for C:AUDJPY on 2026-06-05. Sleeping 60 seconds...
#   [49/90] C:AUDGBP
#   [50/90] C:AUDCNH
#   [51/90] C:AUDCAD
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
# Rate limit hit for C:AUDHKD on 2026-06-05. Sleeping 60 seconds...
#   [54/90] C:AUDSGD
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
#   [57/90] C:CADJPY
#   [58/90] C:CADGBP
# Rate limit hit for C:CADGBP on 2026-06-05. Sleeping 60 seconds...
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-05
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
#   [62/90] C:CADHKD
#   [63/90] C:CADSGD
# Rate limit hit for C:CADSGD on 2026-06-05. Sleeping 60 seconds...
#   [64/90] C:CHFUSD
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
#   [67/90] C:CHFGBP
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-05
#   [69/90] C:CHFAUD
# Rate limit hit for C:CHFAUD on 2026-06-05. Sleeping 60 seconds...
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
# Rate limit hit for C:HKDEUR on 2026-06-05. Sleeping 60 seconds...
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
#   [77/90] C:HKDCNH
# No results for C:HKDCNH on 2026-06-05
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
# Rate limit hit for C:HKDCAD on 2026-06-05. Sleeping 60 seconds...
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
#   [82/90] C:SGDUSD
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# No results for C:SGDCNH on 2026-06-05
#   [87/90] C:SGDAUD
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
# Rate limit hit for C:SGDCHF on 2026-06-05. Sleeping 60 seconds...
#   [90/90] C:SGDHKD
# Got 89264 rows.
# Saved: Data/forex_intraday_2026-06-05.csv
#
# Fetching data for 2026-06-06...
#   [1/90] C:USDEUR
# No results for C:USDEUR on 2026-06-06
#   [2/90] C:USDJPY
# No results for C:USDJPY on 2026-06-06
#   [3/90] C:USDGBP
# No results for C:USDGBP on 2026-06-06
#   [4/90] C:USDCNH
# Rate limit hit for C:USDCNH on 2026-06-06. Sleeping 60 seconds...
# No results for C:USDCNH on 2026-06-06
#   [5/90] C:USDAUD
# No results for C:USDAUD on 2026-06-06
#   [6/90] C:USDCAD
# No results for C:USDCAD on 2026-06-06
#   [7/90] C:USDCHF
# No results for C:USDCHF on 2026-06-06
#   [8/90] C:USDHKD
# No results for C:USDHKD on 2026-06-06
#   [9/90] C:USDSGD
# Rate limit hit for C:USDSGD on 2026-06-06. Sleeping 60 seconds...
# No results for C:USDSGD on 2026-06-06
#   [10/90] C:EURUSD
# No results for C:EURUSD on 2026-06-06
#   [11/90] C:EURJPY
# No results for C:EURJPY on 2026-06-06
#   [12/90] C:EURGBP
# No results for C:EURGBP on 2026-06-06
#   [13/90] C:EURCNH
# No results for C:EURCNH on 2026-06-06
#   [14/90] C:EURAUD
# Rate limit hit for C:EURAUD on 2026-06-06. Sleeping 60 seconds...
# No results for C:EURAUD on 2026-06-06
#   [15/90] C:EURCAD
# No results for C:EURCAD on 2026-06-06
#   [16/90] C:EURCHF
# No results for C:EURCHF on 2026-06-06
#   [17/90] C:EURHKD
# No results for C:EURHKD on 2026-06-06
#   [18/90] C:EURSGD
# No results for C:EURSGD on 2026-06-06
#   [19/90] C:JPYUSD
# No results for C:JPYUSD on 2026-06-06
#   [20/90] C:JPYEUR
# No results for C:JPYEUR on 2026-06-06
#   [21/90] C:JPYGBP
# No results for C:JPYGBP on 2026-06-06
#   [22/90] C:JPYCNH
# Rate limit hit for C:JPYCNH on 2026-06-06. Sleeping 60 seconds...
# No results for C:JPYCNH on 2026-06-06
#   [23/90] C:JPYAUD
# No results for C:JPYAUD on 2026-06-06
#   [24/90] C:JPYCAD
# No results for C:JPYCAD on 2026-06-06
#   [25/90] C:JPYCHF
# No results for C:JPYCHF on 2026-06-06
#   [26/90] C:JPYHKD
# No results for C:JPYHKD on 2026-06-06
#   [27/90] C:JPYSGD
# Rate limit hit for C:JPYSGD on 2026-06-06. Sleeping 60 seconds...
# No results for C:JPYSGD on 2026-06-06
#   [28/90] C:GBPUSD
# No results for C:GBPUSD on 2026-06-06
#   [29/90] C:GBPEUR
# No results for C:GBPEUR on 2026-06-06
#   [30/90] C:GBPJPY
# No results for C:GBPJPY on 2026-06-06
#   [31/90] C:GBPCNH
# No results for C:GBPCNH on 2026-06-06
#   [32/90] C:GBPAUD
# Rate limit hit for C:GBPAUD on 2026-06-06. Sleeping 60 seconds...
# No results for C:GBPAUD on 2026-06-06
#   [33/90] C:GBPCAD
# No results for C:GBPCAD on 2026-06-06
#   [34/90] C:GBPCHF
# No results for C:GBPCHF on 2026-06-06
#   [35/90] C:GBPHKD
# No results for C:GBPHKD on 2026-06-06
#   [36/90] C:GBPSGD
# No results for C:GBPSGD on 2026-06-06
#   [37/90] C:CNHUSD
# Rate limit hit for C:CNHUSD on 2026-06-06. Sleeping 60 seconds...
# No results for C:CNHUSD on 2026-06-06
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-06
#   [39/90] C:CNHJPY
# No results for C:CNHJPY on 2026-06-06
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-06
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-06
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-06
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-06
#   [44/90] C:CNHHKD
# No results for C:CNHHKD on 2026-06-06
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-06
#   [46/90] C:AUDUSD
# No results for C:AUDUSD on 2026-06-06
#   [47/90] C:AUDEUR
# Rate limit hit for C:AUDEUR on 2026-06-06. Sleeping 60 seconds...
# No results for C:AUDEUR on 2026-06-06
#   [48/90] C:AUDJPY
# No results for C:AUDJPY on 2026-06-06
#   [49/90] C:AUDGBP
# No results for C:AUDGBP on 2026-06-06
#   [50/90] C:AUDCNH
# No results for C:AUDCNH on 2026-06-06
#   [51/90] C:AUDCAD
# No results for C:AUDCAD on 2026-06-06
#   [52/90] C:AUDCHF
# Rate limit hit for C:AUDCHF on 2026-06-06. Sleeping 60 seconds...
# No results for C:AUDCHF on 2026-06-06
#   [53/90] C:AUDHKD
# No results for C:AUDHKD on 2026-06-06
#   [54/90] C:AUDSGD
# No results for C:AUDSGD on 2026-06-06
#   [55/90] C:CADUSD
# No results for C:CADUSD on 2026-06-06
#   [56/90] C:CADEUR
# No results for C:CADEUR on 2026-06-06
#   [57/90] C:CADJPY
# Rate limit hit for C:CADJPY on 2026-06-06. Sleeping 60 seconds...
# No results for C:CADJPY on 2026-06-06
#   [58/90] C:CADGBP
# No results for C:CADGBP on 2026-06-06
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-06
#   [60/90] C:CADAUD
# No results for C:CADAUD on 2026-06-06
#   [61/90] C:CADCHF
# No results for C:CADCHF on 2026-06-06
#   [62/90] C:CADHKD
# Rate limit hit for C:CADHKD on 2026-06-06. Sleeping 60 seconds...
# No results for C:CADHKD on 2026-06-06
#   [63/90] C:CADSGD
# No results for C:CADSGD on 2026-06-06
#   [64/90] C:CHFUSD
# No results for C:CHFUSD on 2026-06-06
#   [65/90] C:CHFEUR
# No results for C:CHFEUR on 2026-06-06
#   [66/90] C:CHFJPY
# No results for C:CHFJPY on 2026-06-06
#   [67/90] C:CHFGBP
# No results for C:CHFGBP on 2026-06-06
#   [68/90] C:CHFCNH
# No results for C:CHFCNH on 2026-06-06
#   [69/90] C:CHFAUD
# No results for C:CHFAUD on 2026-06-06
#   [70/90] C:CHFCAD
# No results for C:CHFCAD on 2026-06-06
#   [71/90] C:CHFHKD
# Rate limit hit for C:CHFHKD on 2026-06-06. Sleeping 60 seconds...
# No results for C:CHFHKD on 2026-06-06
#   [72/90] C:CHFSGD
# No results for C:CHFSGD on 2026-06-06
#   [73/90] C:HKDUSD
# No results for C:HKDUSD on 2026-06-06
#   [74/90] C:HKDEUR
# No results for C:HKDEUR on 2026-06-06
#   [75/90] C:HKDJPY
# No results for C:HKDJPY on 2026-06-06
#   [76/90] C:HKDGBP
# Rate limit hit for C:HKDGBP on 2026-06-06. Sleeping 60 seconds...
# No results for C:HKDGBP on 2026-06-06
#   [77/90] C:HKDCNH
# No results for C:HKDCNH on 2026-06-06
#   [78/90] C:HKDAUD
# No results for C:HKDAUD on 2026-06-06
#   [79/90] C:HKDCAD
# No results for C:HKDCAD on 2026-06-06
#   [80/90] C:HKDCHF
# No results for C:HKDCHF on 2026-06-06
#   [81/90] C:HKDSGD
# Rate limit hit for C:HKDSGD on 2026-06-06. Sleeping 60 seconds...
# No results for C:HKDSGD on 2026-06-06
#   [82/90] C:SGDUSD
# No results for C:SGDUSD on 2026-06-06
#   [83/90] C:SGDEUR
# No results for C:SGDEUR on 2026-06-06
#   [84/90] C:SGDJPY
# No results for C:SGDJPY on 2026-06-06
#   [85/90] C:SGDGBP
# No results for C:SGDGBP on 2026-06-06
#   [86/90] C:SGDCNH
# Rate limit hit for C:SGDCNH on 2026-06-06. Sleeping 60 seconds...
# No results for C:SGDCNH on 2026-06-06
#   [87/90] C:SGDAUD
# No results for C:SGDAUD on 2026-06-06
#   [88/90] C:SGDCAD
# No results for C:SGDCAD on 2026-06-06
#   [89/90] C:SGDCHF
# No results for C:SGDCHF on 2026-06-06
#   [90/90] C:SGDHKD
# No results for C:SGDHKD on 2026-06-06
# No data for 2026-06-06, saving empty file.
# Saved: Data/forex_intraday_2026-06-06.csv
#
# Fetching data for 2026-06-07...
#   [1/90] C:USDEUR
#   [2/90] C:USDJPY
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
# Rate limit hit for C:USDAUD on 2026-06-07. Sleeping 60 seconds...
#   [6/90] C:USDCAD
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
# Rate limit hit for C:EURUSD on 2026-06-07. Sleeping 60 seconds...
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
# Rate limit hit for C:EURCAD on 2026-06-07. Sleeping 60 seconds...
#   [16/90] C:EURCHF
#   [17/90] C:EURHKD
#   [18/90] C:EURSGD
#   [19/90] C:JPYUSD
#   [20/90] C:JPYEUR
# Rate limit hit for C:JPYEUR on 2026-06-07. Sleeping 60 seconds...
#   [21/90] C:JPYGBP
#   [22/90] C:JPYCNH
# No results for C:JPYCNH on 2026-06-07
#   [23/90] C:JPYAUD
#   [24/90] C:JPYCAD
#   [25/90] C:JPYCHF
#   [26/90] C:JPYHKD
#   [27/90] C:JPYSGD
# No results for C:JPYSGD on 2026-06-07
#   [28/90] C:GBPUSD
#   [29/90] C:GBPEUR
# Rate limit hit for C:GBPEUR on 2026-06-07. Sleeping 60 seconds...
#   [30/90] C:GBPJPY
#   [31/90] C:GBPCNH
#   [32/90] C:GBPAUD
#   [33/90] C:GBPCAD
#   [34/90] C:GBPCHF
# Rate limit hit for C:GBPCHF on 2026-06-07. Sleeping 60 seconds...
#   [35/90] C:GBPHKD
#   [36/90] C:GBPSGD
#   [37/90] C:CNHUSD
#   [38/90] C:CNHEUR
# No results for C:CNHEUR on 2026-06-07
#   [39/90] C:CNHJPY
# Rate limit hit for C:CNHJPY on 2026-06-07. Sleeping 60 seconds...
#   [40/90] C:CNHGBP
# No results for C:CNHGBP on 2026-06-07
#   [41/90] C:CNHAUD
# No results for C:CNHAUD on 2026-06-07
#   [42/90] C:CNHCAD
# No results for C:CNHCAD on 2026-06-07
#   [43/90] C:CNHCHF
# No results for C:CNHCHF on 2026-06-07
#   [44/90] C:CNHHKD
# Rate limit hit for C:CNHHKD on 2026-06-07. Sleeping 60 seconds...
#   [45/90] C:CNHSGD
# No results for C:CNHSGD on 2026-06-07
#   [46/90] C:AUDUSD
#   [47/90] C:AUDEUR
#   [48/90] C:AUDJPY
#   [49/90] C:AUDGBP
#   [50/90] C:AUDCNH
#   [51/90] C:AUDCAD
#   [52/90] C:AUDCHF
#   [53/90] C:AUDHKD
# Rate limit hit for C:AUDHKD on 2026-06-07. Sleeping 60 seconds...
#   [54/90] C:AUDSGD
#   [55/90] C:CADUSD
#   [56/90] C:CADEUR
#   [57/90] C:CADJPY
#   [58/90] C:CADGBP
# Rate limit hit for C:CADGBP on 2026-06-07. Sleeping 60 seconds...
#   [59/90] C:CADCNH
# No results for C:CADCNH on 2026-06-07
#   [60/90] C:CADAUD
#   [61/90] C:CADCHF
#   [62/90] C:CADHKD
#   [63/90] C:CADSGD
# Rate limit hit for C:CADSGD on 2026-06-07. Sleeping 60 seconds...
#   [64/90] C:CHFUSD
#   [65/90] C:CHFEUR
#   [66/90] C:CHFJPY
#   [67/90] C:CHFGBP
#   [68/90] C:CHFCNH
# Rate limit hit for C:CHFCNH on 2026-06-07. Sleeping 60 seconds...
# No results for C:CHFCNH on 2026-06-07
#   [69/90] C:CHFAUD
#   [70/90] C:CHFCAD
#   [71/90] C:CHFHKD
#   [72/90] C:CHFSGD
#   [73/90] C:HKDUSD
#   [74/90] C:HKDEUR
#   [75/90] C:HKDJPY
#   [76/90] C:HKDGBP
# Rate limit hit for C:HKDGBP on 2026-06-07. Sleeping 60 seconds...
#   [77/90] C:HKDCNH
# No results for C:HKDCNH on 2026-06-07
#   [78/90] C:HKDAUD
#   [79/90] C:HKDCAD
#   [80/90] C:HKDCHF
#   [81/90] C:HKDSGD
# Rate limit hit for C:HKDSGD on 2026-06-07. Sleeping 60 seconds...
#   [82/90] C:SGDUSD
#   [83/90] C:SGDEUR
#   [84/90] C:SGDJPY
#   [85/90] C:SGDGBP
#   [86/90] C:SGDCNH
# Rate limit hit for C:SGDCNH on 2026-06-07. Sleeping 60 seconds...
# No results for C:SGDCNH on 2026-06-07
#   [87/90] C:SGDAUD
#   [88/90] C:SGDCAD
#   [89/90] C:SGDCHF
#   [90/90] C:SGDHKD
# Got 12438 rows.
# Saved: Data/forex_intraday_2026-06-07.csv
#
# Fetching data for 2026-06-08...
#   [1/90] C:USDEUR
# Rate limit hit for C:USDEUR on 2026-06-08. Sleeping 60 seconds...
#   [2/90] C:USDJPY
#   [3/90] C:USDGBP
#   [4/90] C:USDCNH
#   [5/90] C:USDAUD
#   [6/90] C:USDCAD
#   [7/90] C:USDCHF
#   [8/90] C:USDHKD
#   [9/90] C:USDSGD
#   [10/90] C:EURUSD
# Rate limit hit for C:EURUSD on 2026-06-08. Sleeping 60 seconds...
#   [11/90] C:EURJPY
#   [12/90] C:EURGBP
#   [13/90] C:EURCNH
#   [14/90] C:EURAUD
#   [15/90] C:EURCAD
# Rate limit hit for C:EURCAD on 2026-06-08. Sleeping 60 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      14 for i, pair in enumerate(currency_pairs):
#      15     print(f"  [{i+1}/{len(currency_pairs)}] {pair}")
# ---> 16     df = fetch_intraday_forex_data(API_KEY, date_str, pair)
#      17     if df is not None:
#      18         all_data.append(df)
#
# Cell In[11], line 17, in fetch_intraday_forex_data(api_key, date, ticker, timespan, multiplier, max_retries)
#      15 if response.status_code == 429:
#      16     print(f"Rate limit hit for {ticker} on {date}. Sleeping 60 seconds...")
# ---> 17     time.sleep(60)
#      18     retries += 1
#      19     continue
#
# KeyboardInterrupt:
